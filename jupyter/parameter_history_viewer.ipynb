# %%
import glob
import matplotlib.pyplot as plt
import os
import pandas as pd
import sys

sys.path.insert(0, os.path.abspath('../src'))

from alcx_plot import add_timestamps, summarize_historyfile
from alcx_plot import plot_parameter_histograms, plot_parameter_history, plot_parameter_correlation
from pandas.plotting import scatter_matrix

# %%
RUN_FOLDER = os.path.abspath('../../run/')

files = glob.glob(f'{RUN_FOLDER}/parameter_history*.csv')
file_list = add_timestamps(files)
last_file = file_list.iloc[-3].loc['Filename']
print(f'Loading last parameter history file:\n{last_file}')

df = summarize_historyfile(last_file)
# Out:
# Loading last parameter history file:
# /home/m/alchemite/run/parameter_history_20200303-1857h.csv
# (n=200)
#    - Best coefficient of determination = 0.4619 (at idx=123)
#    - Best set of parameters:
#        distribution samples: 605.0
#        gradient directions: 14.0
#        data for gradient: 43.0
#        data for intercept: 1.0
#        iteration layers: 2.0
#        extra data filters: 0.4529871255236315
#        input nodes: 66.0
#        fraction divisions tried: 0.25213042032053923
#        minimum input node correlation: 0.7860456608164613
#        maximum input node intercorrelation: 0.4035511365103046
#        coefficient of determination: 0.4619
#        uncertainty: 0.0038

# %%
plot_parameter_histograms(df)

# %%
plot_parameter_history(df)

# %%
plot_parameter_correlation(df)

# %%
scatter_matrix(df, figsize=(20,20));
